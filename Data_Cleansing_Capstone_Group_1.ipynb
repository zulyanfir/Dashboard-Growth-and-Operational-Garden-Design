# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 9.3 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0

# %%
# import libraries
import mysql.connector
from mysql.connector import Error

# %%
# import pandas
import pandas as pd

#import matplotlib
import matplotlib.pyplot as plt

# import warning to ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
# define mysql details
host   = 'okegarden-laravel-prod-db-2024-11-15-0200.cgwhhgh85mr3.ap-southeast-3.rds.amazonaws.com'
port   = '3306'
user   = 'intern_mes'
passwd = 'sdfDFLES342982Ddlsdksd'
databs = 'okegarden_laravel_prod_db'

# %%
# function to fetch data from database, the connection is closed after use.
def fetch_data(host_name, port_name, user_name, user_password, db_name, query, params=None):
    try:
        # use with to ensure the connection is closed after use
        with mysql.connector.connect(
            host=host_name,
            port=port_name,
            user=user_name,
            password=user_password,
            database=db_name
        ) as connection:
            data = pd.read_sql(query, connection, params=params) # read the query to dataframe format
            return data

    except Error as e:
        print(f"Error while connecting to MySQL or fetching data: {e}")
        return None

# %%
#Table yang digunakan
order_design
activity_log
desc_design (RAB)
design
order_garden
address_component
datetime

# %% [markdown]
# # **Tabel order_design**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from order_design limit 100;

"""

# %%
# fetch data using function
df_order_design = fetch_data(host, port, user, passwd, databs, query)

# %%
# show data
df_order_design
# Out:
#     id_order  id_user  id_promo id_category  id_designer  id_design_finish  \
# 0        568      921      26.0           3        949.0             244.0
# 1        569      923      26.0           1        950.0             236.0
# 2        570      925      26.0           4        943.0             214.0
# 3        571      926      26.0           3        946.0             219.0
# 4        572      927      30.0           2        928.0             213.0
# ..       ...      ...       ...         ...          ...               ...
# 95       663     1106      32.0           1       1128.0             346.0
# 96       664     1107      32.0           2        940.0             321.0
# 97       665     1110      32.0           6        997.0             345.0
# 98       666     1111      32.0           3        983.0             369.0
# 99       667      899       NaN           1          NaN               NaN
#
#    size_area                                              photo  \
# 0       None  ["laravel/order-design/99f5fcb9-ae17-4c8b-8e55...
# 1       None  ["laravel/order-design/b07dc7e1-246e-4089-9e35...
# 2       None  ["laravel/order-design/6fda17c5-4ae0-4ad6-ae98...
# 3       None  ["laravel/order-design/c28ceb45-6d6e-4782-84fc...
# 4       None  ["laravel/order-design/0b09558d-4ff7-4ee7-8b40...
# ..       ...                                                ...
# 95      None  ["laravel\/order-design\/4d0a9be9-e68c-4597-82...
# 96      None  ["laravel\/order-design\/da078122-6bb4-400b-9f...
# 97        51  ["laravel\/order-design\/0e231a7a-46ad-453c-ac...
# 98      None  ["laravel\/order-design\/a7d7f4f1-aa97-4a0d-98...
# 99      None  ["laravel\/order-design\/129b66ed-a39d-499c-b6...
#
#                                               address  rating  ...  \
# 0   Emerald View, Jln. Emerald Citra V, Blok D no....     NaN  ...
# 1   Perumahan Jatinegara Indah, Jl Lawu Ujung Blok...     NaN  ...
# 2   Premier Terrace Blok M3, Jalan Raya Ciracas, C...     5.0  ...
# 3   Mahagoni Park Bintaro Blok B1 No 50, Perigi Ba...     3.0  ...
# 4   Jl. Ujung Gedong RT 002 RW 012 no.69 Kel. Gedo...     5.0  ...
# ..                                                ...     ...  ...
# 95  Jl Duren sawit timur IV, Komplek PTB Blok Q5/1...     5.0  ...
# 96  jl sutera victoria utama no 19 cluster victori...     NaN  ...
# 97  jln Sari Ibun no 27. Villa duta, Bogor, Kabupa...     NaN  ...
# 98  mozart signature 2A no. 7, Kota Jakarta Utara,...     NaN  ...
# 99  komplek\r\nrinjani\r\nno\r\n25, Kota Cimahi, J...     NaN  ...
#
#                                url_wa_group_internal  \
# 0   https://chat.whatsapp.com/BUtBzn2Qk2JDOEo4NvHcSF
# 1   https://chat.whatsapp.com/EH8CxTK4P9H01hnl1yPnHU
# 2   https://chat.whatsapp.com/ILtRiPtf3Vu5uTcVEHHEtH
# 3   https://chat.whatsapp.com/ElEFANLwKS7ImewBndmvdI
# 4   https://chat.whatsapp.com/CCcYR4ciF5DHef6pWkKiXN
# ..                                               ...
# 95                                              None
# 96                                              None
# 97                                              None
# 98                                              None
# 99                                              None
#
#                                           client_note  \
# 0   Taman kering jepang minimalis. Focal point 1 b...
# 1                                  Hanya bagian tanah
# 2             Desain minimalis modern minim perawatan
# 3   - Pinggir kiri calathea\r\n- depan heliconia,\...
# 4
# ..                                                ...
# 95
# 96
# 97
# 98
# 99                                            dsadfas
#
#                                 presentation_file_url  id_order_garden  \
# 0   https://drive.google.com/file/d/1dbzDjCNCfXxDD...             None
# 1   https://drive.google.com/file/d/1Uc9FBLWLgd2z_...             None
# 2   https://docs.google.com/presentation/d/1COkFs_...             None
# 3   https://drive.google.com/file/d/1TkSU3sjLtuLaS...             None
# 4                                                None             None
# ..                                                ...              ...
# 95  https://drive.google.com/drive/folders/1iPFPoi...             None
# 96  https://drive.google.com/file/d/11Bd4eZzXMuGCI...             None
# 97                                                                None
# 98  https://docs.google.com/spreadsheets/d/17GVAQN...             None
# 99                                               None             None
#
#     consultation_date  consultation_time  id_po_scheme id_parent design_count  \
# 0                None               None           NaN      None          NaN
# 1                None               None           NaN      None          NaN
# 2                None               None           NaN      None          NaN
# 3                None               None           NaN      None          NaN
# 4                None               None           NaN      None          NaN
# ..                ...                ...           ...       ...          ...
# 95               None               None           NaN      None          NaN
# 96               None               None           NaN      None          NaN
# 97               None               None           NaN      None          NaN
# 98               None               None           NaN      None          NaN
# 99               None               None           NaN      None          NaN
#
#    deleted_at
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# ..        ...
# 95       None
# 96       None
# 97       None
# 98       None
# 99       None
#
# [100 rows x 32 columns]

# %%
# show info
df_order_design.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_order               100 non-null    int64
#  1   id_user                100 non-null    int64
#  2   id_promo               91 non-null     float64
#  3   id_category            100 non-null    object
#  4   id_designer            85 non-null     float64
#  5   id_design_finish       81 non-null     float64
#  6   size_area              13 non-null     object
#  7   photo                  100 non-null    object
#  8   address                100 non-null    object
#  9   rating                 20 non-null     float64
#  10  testimoni              6 non-null      object
#  11  status                 100 non-null    object
#  12  date                   0 non-null      object
#  13  price                  100 non-null    float64
#  14  province               100 non-null    int64
#  15  city                   100 non-null    int64
#  16  total_promo            100 non-null    float64
#  17  link_payment           21 non-null     object
#  18  created_at             100 non-null    datetime64[ns]
#  19  updated_at             100 non-null    datetime64[ns]
#  20  poin_revisi            0 non-null      object
#  21  url_wa_group_client    17 non-null     object
#  22  url_wa_group_internal  16 non-null     object
#  23  client_note            100 non-null    object
#  24  presentation_file_url  80 non-null     object
#  25  id_order_garden        0 non-null      object
#  26  consultation_date      0 non-null      object
#  27  consultation_time      0 non-null      object
#  28  id_po_scheme           1 non-null      float64
#  29  id_parent              0 non-null      object
#  30  design_count           1 non-null      float64
#  31  deleted_at             0 non-null      object
# dtypes: datetime64[ns](2), float64(8), int64(4), object(18)
# memory usage: 25.1+ KB

# %% [markdown]
# # **Tabel activity_log**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from activity_log limit 100;

"""

# %%
# fetch data using function
df_activity_log = fetch_data(host, port, user, passwd, databs, query)

# show data
df_activity_log
# Out:
#      id log_name description                      subject_type    event  \
# 0     1  default     created                   App\Models\User  created
# 1     2  default     created            App\Models\UserAddress  created
# 2     3  default     created            App\Models\OrderDesign  created
# 3     4  default     created                  App\Models\Image  created
# 4     5  default     created                  App\Models\Image  created
# ..  ...      ...         ...                               ...      ...
# 95   96  default     created            App\Models\OrderDesign  created
# 96   97  default     updated            App\Models\OrderDesign  updated
# 97   98  default     created        App\Models\NotificationLog  created
# 98   99  default     created        App\Models\OrderGardenCare  created
# 99  100  default     created  App\Models\OrderGardenCareDetail  created
#
#     subject_id      causer_type  causer_id  \
# 0         1833             None        NaN
# 1          767  App\Models\User     1833.0
# 2          961  App\Models\User     1833.0
# 3         2061  App\Models\User     1833.0
# 4         2062  App\Models\User     1833.0
# ..         ...              ...        ...
# 95         962  App\Models\User     1600.0
# 96         962  App\Models\User     1600.0
# 97         524  App\Models\User     1600.0
# 98         247  App\Models\User     1242.0
# 99        1323  App\Models\User     1242.0
#
#                                            properties batch_uuid  \
# 0   {"attributes":{"id_user":1833,"id_role":1,"nam...       None
# 1   {"attributes":{"id_user_address":767,"id_user"...       None
# 2   {"attributes":{"id_order":961,"id_user":1833,"...       None
# 3   {"attributes":{"id":2061,"url":"https:\/\/okeg...       None
# 4   {"attributes":{"id":2062,"url":"https:\/\/okeg...       None
# ..                                                ...        ...
# 95  {"attributes":{"id_order":962,"id_user":1600,"...       None
# 96  {"attributes":{"id_order":962,"id_user":1600,"...       None
# 97  {"attributes":{"id":524,"name":"notifyNewOrder...       None
# 98  {"attributes":{"id":247,"id_user":1242,"id_gar...       None
# 99  {"attributes":{"id":1323,"id_order_garden_care...       None
#
#             created_at          updated_at
# 0  2024-10-21 15:54:24 2024-10-21 15:54:24
# 1  2024-10-21 15:57:51 2024-10-21 15:57:51
# 2  2024-10-21 16:00:39 2024-10-21 16:00:39
# 3  2024-10-21 16:00:39 2024-10-21 16:00:39
# 4  2024-10-21 16:00:39 2024-10-21 16:00:39
# ..                 ...                 ...
# 95 2024-10-22 11:38:31 2024-10-22 11:38:31
# 96 2024-10-22 11:38:31 2024-10-22 11:38:31
# 97 2024-10-22 11:38:32 2024-10-22 11:38:32
# 98 2024-10-22 11:39:47 2024-10-22 11:39:47
# 99 2024-10-22 11:39:47 2024-10-22 11:39:47
#
# [100 rows x 12 columns]

# %%
# show info
df_activity_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            100 non-null    int64
#  1   log_name      100 non-null    object
#  2   description   100 non-null    object
#  3   subject_type  100 non-null    object
#  4   event         100 non-null    object
#  5   subject_id    100 non-null    int64
#  6   causer_type   75 non-null     object
#  7   causer_id     75 non-null     float64
#  8   properties    100 non-null    object
#  9   batch_uuid    0 non-null      object
#  10  created_at    100 non-null    datetime64[ns]
#  11  updated_at    100 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(7)
# memory usage: 9.5+ KB

# %% [markdown]
# # **Tabel desc_design (RAB)**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from desc_design limit 100;

"""

# %%
# fetch data using function
df_desc_design = fetch_data(host, port, user, passwd, databs, query)

# show data
df_desc_design
# Out:
#     id_desc  id_design  id_item  volume     category denom  \
# 0       392         14        1   100.0        plant  None
# 1       393         14        1   300.0  operational  None
# 2       394         14        3   200.0     material  None
# 3       399         13        1     1.0        plant  None
# 4       400         13        1     1.0  operational  None
# ..      ...        ...      ...     ...          ...   ...
# 95     2049         56       16     1.0        plant  unit
# 96     2050         56       24     3.0        plant  unit
# 97     2051         56      217     1.0        plant    m2
# 98     2052         56       92     1.2        plant     m
# 99     2053         56       22     2.0        plant  unit
#
#             created_at          updated_at  \
# 0  2022-02-13 09:01:26 2024-11-05 18:38:11
# 1  2022-02-13 09:01:26 2024-11-05 18:38:11
# 2  2022-02-13 09:01:26 2024-11-05 18:38:11
# 3  2022-02-13 10:06:26 2024-11-05 18:38:11
# 4  2022-02-13 10:06:26 2024-11-05 18:38:11
# ..                 ...                 ...
# 95 2022-03-23 05:08:54 2024-11-05 18:38:11
# 96 2022-03-23 05:08:54 2024-11-05 18:38:11
# 97 2022-03-23 05:08:54 2024-11-05 18:38:11
# 98 2022-03-23 05:08:54 2024-11-05 18:38:11
# 99 2022-03-23 05:08:54 2024-11-05 18:38:11
#
#                                             item_name  \
# 0                                     Adam Hawa d: 15
# 1   Pengolahan lahan biasa + Penanaman (harga per m2)
# 2   Paket Lampu taman dinding (lampu tegak, bohlam...
# 3                                     Adam Hawa d: 15
# 4   Pengolahan lahan biasa + Penanaman (harga per m2)
# ..                                                ...
# 95                           Bromelia Debora d: 25 cm
# 96                         Bromelia tricolor d: 25 cm
# 97                                 Kucai mini d: 3 cm
# 98                                 Sanseviera t: 40cm
# 99                            Bromelia merah d: 30 cm
#
#                                            item_photo  item_unit_qty  \
# 0   laravel/plant/168_plant_5ffcf8e8e749a96b71a85e...           1300
# 1                                                None            300
# 2   laravel/material/130b4ea0-2dc2-4432-89b4-c053a...            200
# 3   laravel/plant/168_plant_5ffcf8e8e749a96b71a85e...             13
# 4                                                None              1
# ..                                                ...            ...
# 95  laravel/plant/697_plant_a2ba73efd6f76ff2faafca...              1
# 96  laravel/plant/295_plant_0c4ab43c6295f3e39dd4ee...              3
# 97  laravel/plant/421_plant_e878520f7579d4fba3e0ff...              1
# 98  laravel/plant/578_plant_7802531fe3bc9fee61bcf1...             15
# 99  laravel/plant/149_plant_8551db1febd47145f66501...              2
#
#     item_unit_cost  item_unit_price  item_denom_cost  item_denom_price  \
# 0             4000             8000             4000              8000
# 1            80000            80000                0             80000
# 2           275000           500000           275000            500000
# 3             4000             8000             4000              8000
# 4            80000            80000                0             80000
# ..             ...              ...              ...               ...
# 95          120000           396000           120000            396000
# 96           30000            90000            30000             90000
# 97          250000           350000           250000            350000
# 98            6000            15000            72000            180000
# 99           35000           105000            35000            105000
#
#     item_total_cost  item_total_price
# 0            400000            800000
# 1                 0          24000000
# 2          55000000         100000000
# 3              4000              8000
# 4                 0             80000
# ..              ...               ...
# 95           120000            396000
# 96            90000            270000
# 97           250000            350000
# 98            86400            216000
# 99            70000            210000
#
# [100 rows x 17 columns]

# %%
# show info
df_desc_design.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_desc           100 non-null    int64
#  1   id_design         100 non-null    int64
#  2   id_item           100 non-null    int64
#  3   volume            100 non-null    float64
#  4   category          100 non-null    object
#  5   denom             90 non-null     object
#  6   created_at        100 non-null    datetime64[ns]
#  7   updated_at        100 non-null    datetime64[ns]
#  8   item_name         100 non-null    object
#  9   item_photo        82 non-null     object
#  10  item_unit_qty     100 non-null    int64
#  11  item_unit_cost    100 non-null    int64
#  12  item_unit_price   100 non-null    int64
#  13  item_denom_cost   100 non-null    int64
#  14  item_denom_price  100 non-null    int64
#  15  item_total_cost   100 non-null    int64
#  16  item_total_price  100 non-null    int64
# dtypes: datetime64[ns](2), float64(1), int64(10), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# # **Tabel design**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from design limit 100;

"""

# %%
# fetch data using function
df_design = fetch_data(host, port, user, passwd, databs, query)

# show data
df_design
# Out:
#     id_design  id_category  id_user  id_type               design_name  area  \
# 0           2            1       14        2    Taman Kering Minimalis  None
# 1           5            1       14        3      Taman Asri Minimalis  None
# 2           6            1       14        3    Taman Asri Minimalis 2  None
# 3           7            1       14        2  Taman Kering Minimalis 2  None
# 4           8            2       14        1                Green Mate  None
# ..        ...          ...      ...      ...                       ...   ...
# 95        101            5       14        1            Minima Sunbath  None
# 96        102            6       14        3                Minima Gem  None
# 97        103            3      178        2             Taman Melissa  None
# 98        104            3      206        3          Taman Prima Sari  None
# 99        105            1      177        3               Taman Widhi  None
#
#    absortion                                            image_f  \
# 0       None  laravel/design/_ImageF_2f0b180bc29750f3a798b95...
# 1       None  laravel/design/_ImageF_ea9f4a5c1d9914fc785177b...
# 2       None  laravel/design/_ImageF_5bb7dcb9929b08402c09516...
# 3       None  laravel/design/_ImageF_cdaa3269d5cc18f5a9f39a9...
# 4       None  laravel/design/_ImageF_559b9c30790b2b4987493cd...
# ..       ...                                                ...
# 95      None  laravel/design/_ImageF_493f4beb6988ff73faeebcd...
# 96      None  laravel/design/_ImageF_1218878f1ad901a759b75a9...
# 97      None  laravel/design/210_ImageF_e00cc6439a67800946b2...
# 98      None  laravel/design/184_ImageF_feb898296623d5d791b7...
# 99      None  laravel/design/244_ImageF_20c912b713cc36561c52...
#
#                                               image_b  \
# 0   laravel/design/_ImageB_766c9e6f1e4431e239c4d11...
# 1   laravel/design/_ImageB_ea9f4a5c1d9914fc785177b...
# 2   laravel/design/_ImageB_5bb7dcb9929b08402c09516...
# 3   laravel/design/_ImageB_cdaa3269d5cc18f5a9f39a9...
# 4   laravel/design/_ImageB_f551feeab2cf87f5e0fc628...
# ..                                                ...
# 95  laravel/design/_ImageB_0d55f16176da5bf9179fe0d...
# 96  laravel/design/_ImageB_1218878f1ad901a759b75a9...
# 97  laravel/design/210_ImageB_e00cc6439a67800946b2...
# 98  laravel/design/184_ImageB_efead4a4cb152b3bbfa0...
# 99  laravel/design/244_ImageB_20c912b713cc36561c52...
#
#                                               image_l  ...  \
# 0   laravel/design/_ImageL_766c9e6f1e4431e239c4d11...  ...
# 1   laravel/design/_ImageL_ea9f4a5c1d9914fc785177b...  ...
# 2   laravel/design/_ImageL_5bb7dcb9929b08402c09516...  ...
# 3   laravel/design/_ImageL_cdaa3269d5cc18f5a9f39a9...  ...
# 4   laravel/design/_ImageL_f551feeab2cf87f5e0fc628...  ...
# ..                                                ...  ...
# 95  laravel/design/_ImageL_0d55f16176da5bf9179fe0d...  ...
# 96  laravel/design/_ImageL_1218878f1ad901a759b75a9...  ...
# 97  laravel/design/210_ImageL_f104802d0435541554fd...  ...
# 98  laravel/design/184_ImageL_efead4a4cb152b3bbfa0...  ...
# 99  laravel/design/244_ImageL_20c912b713cc36561c52...  ...
#
#             created_at          updated_at display deleted_at id_mandor  \
# 0  2022-01-18 05:54:24 2024-08-29 10:00:25       0        NaT      None
# 1  2022-01-18 21:31:15 2024-08-29 10:01:57       0        NaT      None
# 2  2022-01-18 21:57:08 2024-08-29 10:05:40       0        NaT      None
# 3  2022-01-19 02:02:16 2024-08-29 10:06:25       0        NaT      None
# 4  2022-01-19 03:11:36 2024-08-29 10:27:04       0        NaT      None
# ..                 ...                 ...     ...        ...       ...
# 95 2022-04-01 13:59:30 2024-06-25 11:51:32       0        NaT      None
# 96 2022-04-01 14:10:10 2024-06-25 11:51:41       0        NaT      None
# 97 2022-04-03 14:17:26 2024-04-17 16:00:31       0        NaT      None
# 98 2022-04-04 16:11:04 2024-08-29 10:29:26       0        NaT      None
# 99 2022-04-07 05:53:38 2024-04-17 16:00:31       0        NaT      None
#
#    nama_client image_5 image_6 link_presentation_file  id_parent
# 0         None    None    None                              None
# 1         None    None    None                              None
# 2         None    None    None                              None
# 3         None    None    None                              None
# 4         None    None    None                              None
# ..         ...     ...     ...                    ...        ...
# 95        None    None    None                   None       None
# 96        None    None    None                   None       None
# 97        None    None    None                   None       None
# 98        None    None    None                              None
# 99        None    None    None                   None       None
#
# [100 rows x 27 columns]

# %%
# show info
df_design.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_design               100 non-null    int64
#  1   id_category             100 non-null    int64
#  2   id_user                 100 non-null    int64
#  3   id_type                 100 non-null    int64
#  4   design_name             100 non-null    object
#  5   area                    0 non-null      object
#  6   absortion               0 non-null      object
#  7   image_f                 100 non-null    object
#  8   image_b                 100 non-null    object
#  9   image_l                 100 non-null    object
#  10  image_r                 100 non-null    object
#  11  price                   0 non-null      object
#  12  nursing                 0 non-null      object
#  13  status                  100 non-null    object
#  14  description             85 non-null     object
#  15  price_per_meter         0 non-null      object
#  16  documentation           2 non-null      object
#  17  created_at              100 non-null    datetime64[ns]
#  18  updated_at              100 non-null    datetime64[ns]
#  19  display                 100 non-null    int64
#  20  deleted_at              31 non-null     datetime64[ns]
#  21  id_mandor               0 non-null      object
#  22  nama_client             0 non-null      object
#  23  image_5                 0 non-null      object
#  24  image_6                 0 non-null      object
#  25  link_presentation_file  21 non-null     object
#  26  id_parent               0 non-null      object
# dtypes: datetime64[ns](3), int64(5), object(19)
# memory usage: 21.2+ KB

# %% [markdown]
# # **Tabel order_garden**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from order_garden limit 100;

"""

# %%
# fetch data using function
df_order_garden = fetch_data(host, port, user, passwd, databs, query)

# show data
df_order_garden
# Out:
#     id_order  id_garden  id_design  id_user  id_promo  size_area  \
# 0         65        NaN        213      927      35.0       11.0
# 1         66        NaN        219      926      37.0       28.0
# 2         69        NaN        214      925       NaN       35.0
# 3         70        NaN        214      925       NaN       35.0
# 4         72        NaN        259     1024       NaN        2.0
# ..       ...        ...        ...      ...       ...        ...
# 95       189        NaN        553       17      77.0       10.0
# 96       190        NaN        513     1707       NaN       16.0
# 97       191        NaN        483     1607       NaN        8.0
# 98       192        NaN        534     1727       NaN        8.0
# 99       193        NaN        494      916       NaN       21.0
#
#                                                 photo  \
# 0   ["laravel/order-design/0b09558d-4ff7-4ee7-8b40...
# 1   ["laravel/order-design/c28ceb45-6d6e-4782-84fc...
# 2   ["laravel\/order-design\/6fda17c5-4ae0-4ad6-ae...
# 3   ["laravel\/order-design\/6fda17c5-4ae0-4ad6-ae...
# 4   ["laravel\/order-design\/aada95b5-5371-4cbc-a9...
# ..                                                ...
# 95                                                 []
# 96  ["laravel\/order-design\/1ae85e5c-bec9-4877-a2...
# 97  ["laravel\/order-design\/c88c54b7-3837-4c4f-b7...
# 98  ["laravel\/order-design\/d80f3627-9ac6-4e5c-86...
# 99  ["laravel\/order-design\/dd7e7009-ee7f-45f5-89...
#
#                                               address id_designer  \
# 0   Jl. Ujung Gedong RT 002 RW 012 no.69 Kel. Gedo...        None
# 1   Mahagoni Park Bintaro Blok B1 No 50, Perigi Ba...        None
# 2   Premier Terrace Blok M3, Jalan Raya Ciracas, C...        None
# 3   Premier Terrace Blok M3, Jalan Raya Ciracas, C...        None
# 4                     Bekasi, Kota Bekasi, Jawa Barat        None
# ..                                                ...         ...
# 95  Gedung Setiabudi 2 Lantai 2 Suite 207B-C Jl. H...        None
# 96  Serenia Hills, Jl. Venture Barat no 32, Tanger...        None
# 97  cluster Alicante Granada blok ABB no.27 Gading...        None
# 98  Jl. Darmawangsa X No. 69A, Kebayoran Baru, Jak...        None
# 99     Gading Serpong, Kota Tangerang Selatan, Banten        None
#
#     id_gardener  ...                           link_design_presentation  \
# 0        1087.0  ...                                               None
# 1        1093.0  ...                                               None
# 2           NaN  ...                                               None
# 3        1085.0  ...                                               None
# 4        1087.0  ...                                               None
# ..          ...  ...                                                ...
# 95          NaN  ...
# 96       1093.0  ...                                               None
# 97       1093.0  ...                                               None
# 98       1092.0  ...  https://drive.google.com/file/d/1H_4sXn7tYDqUe...
# 99          NaN  ...  https://drive.google.com/file/d/1UG_g8CNtCkMT6...
#
#    link_operational_offer id_po_scheme po_day_wait  fulfillment_boq_sent_at  \
# 0                    None         None        None                      NaT
# 1                    None         None        None                      NaT
# 2                    None         None        None                      NaT
# 3                    None         None        None                      NaT
# 4                    None         None        None                      NaT
# ..                    ...          ...         ...                      ...
# 95                   None         None        None                      NaT
# 96                   None         None        None                      NaT
# 97                   None         None        None                      NaT
# 98                   None         None        None                      NaT
# 99                   None         None        None                      NaT
#
#     mandor_briefed_at  url_file_storage  contract_signed_at  \
# 0                 NaT              None                 NaT
# 1                 NaT              None                 NaT
# 2                 NaT              None                 NaT
# 3                 NaT              None                 NaT
# 4                 NaT              None                 NaT
# ..                ...               ...                 ...
# 95                NaT              None 2024-10-25 17:33:30
# 96                NaT              None                 NaT
# 97                NaT              None                 NaT
# 98                NaT              None 2024-10-28 17:04:03
# 99                NaT              None                 NaT
#
#    warranty_terms_signed_at          deleted_at
# 0                       NaT                 NaT
# 1                       NaT                 NaT
# 2                       NaT                 NaT
# 3                       NaT                 NaT
# 4                       NaT                 NaT
# ..                      ...                 ...
# 95      2024-10-25 17:33:30 2024-11-07 16:28:42
# 96                      NaT                 NaT
# 97                      NaT                 NaT
# 98      2024-10-28 17:04:03 2024-11-11 10:32:18
# 99                      NaT 2024-11-04 07:14:58
#
# [100 rows x 41 columns]

# %%
# show info
df_order_garden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_order                  100 non-null    int64
#  1   id_garden                 1 non-null      float64
#  2   id_design                 100 non-null    int64
#  3   id_user                   100 non-null    int64
#  4   id_promo                  31 non-null     float64
#  5   size_area                 100 non-null    float64
#  6   photo                     100 non-null    object
#  7   address                   100 non-null    object
#  8   id_designer               0 non-null      object
#  9   id_gardener               87 non-null     float64
#  10  rating                    6 non-null      float64
#  11  testimoni                 4 non-null      object
#  12  status                    100 non-null    object
#  13  date                      0 non-null      object
#  14  price                     100 non-null    float64
#  15  province                  100 non-null    int64
#  16  city                      100 non-null    int64
#  17  total_promo               99 non-null     float64
#  18  link_payment              26 non-null     object
#  19  created_at                100 non-null    datetime64[ns]
#  20  updated_at                100 non-null    datetime64[ns]
#  21  need_design               1 non-null      object
#  22  id_design_finish          99 non-null     float64
#  23  id_garden_finish          74 non-null     float64
#  24  url_wa_group_client       7 non-null      object
#  25  url_wa_group_internal     7 non-null      object
#  26  client_note               9 non-null      object
#  27  gardener_note             1 non-null      object
#  28  link_file_progress        8 non-null      object
#  29  id_order_garden_care      66 non-null     float64
#  30  admin_note                5 non-null      object
#  31  link_design_presentation  56 non-null     object
#  32  link_operational_offer    0 non-null      object
#  33  id_po_scheme              0 non-null      object
#  34  po_day_wait               0 non-null      object
#  35  fulfillment_boq_sent_at   2 non-null      datetime64[ns]
#  36  mandor_briefed_at         12 non-null     datetime64[ns]
#  37  url_file_storage          0 non-null      object
#  38  contract_signed_at        14 non-null     datetime64[ns]
#  39  warranty_terms_signed_at  14 non-null     datetime64[ns]
#  40  deleted_at                4 non-null      datetime64[ns]
# dtypes: datetime64[ns](7), float64(10), int64(5), object(19)
# memory usage: 32.2+ KB

# %% [markdown]
# # **Tabel address_components**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from address_components limit 100;

"""

# %%
# fetch data using function
df_address_components = fetch_data(host, port, user, passwd, databs, query)

# show data
df_address_components
# Out:
#      id  address_componentable_id  address_componentable_type geocoder  \
# 0     1                         3  App\Models\OrderGardenCare   google
# 1     2                         4  App\Models\OrderGardenCare   google
# 2     3                         5  App\Models\OrderGardenCare   google
# 3     4                         6  App\Models\OrderGardenCare   google
# 4     5                         7  App\Models\OrderGardenCare   google
# ..  ...                       ...                         ...      ...
# 95   96                        98  App\Models\OrderGardenCare   google
# 96   97                        99  App\Models\OrderGardenCare   google
# 97   98                       100  App\Models\OrderGardenCare   google
# 98   99                       101  App\Models\OrderGardenCare   google
# 99  100                       102  App\Models\OrderGardenCare   google
#
#       latitude    longitude    country    administrative_area_level_1  \
# 0   -6.2607624  106.6903235  Indonesia                         Banten
# 1   -6.3298427  106.8758824  Indonesia                        Jakarta
# 2   -6.2382699  106.9755726  Indonesia                      West Java
# 3   -6.3634654  106.8803617  Indonesia  Daerah Khusus Ibukota Jakarta
# 4   -6.2358184  106.5764758  Indonesia                         Banten
# ..         ...          ...        ...                            ...
# 95  -6.3213441  106.7917897  Indonesia                     Jawa Barat
# 96  -6.2289307  106.7085006  Indonesia                         Banten
# 97  -6.3764328  106.8887136  Indonesia                     Jawa Barat
# 98  -6.1896385  106.8244039  Indonesia  Daerah Khusus Ibukota Jakarta
# 99   -6.193458  106.7851649  Indonesia  Daerah Khusus Ibukota Jakarta
#
#    administrative_area_level_2 administrative_area_level_3  \
# 0            Tangerang Selatan                 Pondok Aren
# 1            East Jakarta City                     Ciracas
# 2                       Bekasi
# 3                Jakarta Timur                     Ciracas
# 4                    Tangerang                       Curug
# ..                         ...                         ...
# 95                       Depok                      Cinere
# 96                   Tangerang                     Ciledug
# 97                       Depok                   Cimanggis
# 98               Jakarta Pusat                     Menteng
# 99               Jakarta Barat                    Palmerah
#
#    administrative_area_level_4 postal_code          created_at  \
# 0                  Parigi Baru       15228 2024-11-06 23:32:48
# 1                      Ciracas       13740 2024-11-06 23:32:48
# 2                                          2024-11-06 23:32:48
# 3                      Cibubur       13720 2024-11-06 23:32:48
# 4                         Kadu             2024-11-06 23:32:49
# ..                         ...         ...                 ...
# 95              Pangkalan Jati       16513 2024-11-07 16:35:17
# 96               Sudimara Jaya       15151 2024-11-07 16:35:17
# 97                  Harjamukti       16454 2024-11-07 16:35:17
# 98                  Gondangdia       10350 2024-11-07 16:35:18
# 99                    Palmerah       11480 2024-11-07 16:35:18
#
#             updated_at full_address
# 0  2024-11-06 23:32:48         None
# 1  2024-11-06 23:32:48         None
# 2  2024-11-06 23:32:48         None
# 3  2024-11-06 23:32:48         None
# 4  2024-11-06 23:32:49         None
# ..                 ...          ...
# 95 2024-11-07 16:35:17         None
# 96 2024-11-07 16:35:17         None
# 97 2024-11-07 16:35:17         None
# 98 2024-11-07 16:35:18         None
# 99 2024-11-07 16:35:18         None
#
# [100 rows x 15 columns]

# %%
#Show info
df_address_components.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           100 non-null    int64
#  1   address_componentable_id     100 non-null    int64
#  2   address_componentable_type   100 non-null    object
#  3   geocoder                     100 non-null    object
#  4   latitude                     100 non-null    object
#  5   longitude                    100 non-null    object
#  6   country                      100 non-null    object
#  7   administrative_area_level_1  100 non-null    object
#  8   administrative_area_level_2  100 non-null    object
#  9   administrative_area_level_3  100 non-null    object
#  10  administrative_area_level_4  100 non-null    object
#  11  postal_code                  100 non-null    object
#  12  created_at                   100 non-null    datetime64[ns]
#  13  updated_at                   100 non-null    datetime64[ns]
#  14  full_address                 0 non-null      object
# dtypes: datetime64[ns](2), int64(2), object(11)
# memory usage: 11.8+ KB

# %% [markdown]
# # **Tabel datetime**

# %%
# usage example (the mysql detail already defined)
# simple query
query= """

select * from datetime limit 100;

"""

# %%
# fetch data using function
df_datetime = fetch_data(host, port, user, passwd, databs, query)

# show data
df_datetime
# Out:
#      id            datetime                    type  datetimeable_id  \
# 0     1 2024-08-24 00:00:00   garden_build_schedule              124
# 1     2 2024-08-16 00:00:00   garden_build_schedule              102
# 2     3 2024-08-31 00:00:00   garden_build_schedule              125
# 3     6 2024-09-29 00:00:00   garden_build_schedule              126
# 4     7 2024-08-24 00:00:00   garden_build_schedule              135
# ..  ...                 ...                     ...              ...
# 95  106 2024-11-09 16:33:10  actual_completion_date              943
# 96  107 2024-11-16 00:00:00   garden_build_schedule              208
# 97  108 2024-11-10 00:00:00      planned_start_date             1000
# 98  109 2024-11-11 09:35:21       actual_start_date              999
# 99  110 2024-11-11 09:35:40       actual_start_date              995
#
#          datetimeable_type          created_at          updated_at
# 0   App\Models\OrderGarden 2024-08-15 11:31:11 2024-08-16 06:56:00
# 1   App\Models\OrderGarden 2024-08-15 11:31:34 2024-08-15 11:31:34
# 2   App\Models\OrderGarden 2024-08-15 17:13:24 2024-08-15 17:13:24
# 3   App\Models\OrderGarden 2024-08-18 13:55:23 2024-08-18 13:55:23
# 4   App\Models\OrderGarden 2024-08-20 06:22:03 2024-08-20 06:22:03
# ..                     ...                 ...                 ...
# 95  App\Models\OrderDesign 2024-11-09 16:33:10 2024-11-09 16:33:10
# 96  App\Models\OrderGarden 2024-11-09 16:44:23 2024-11-09 16:44:23
# 97  App\Models\OrderDesign 2024-11-11 09:31:39 2024-11-11 09:47:16
# 98  App\Models\OrderDesign 2024-11-11 09:35:21 2024-11-11 09:35:21
# 99  App\Models\OrderDesign 2024-11-11 09:35:40 2024-11-11 09:35:40
#
# [100 rows x 7 columns]

# %%
# show info
df_datetime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    int64
#  1   datetime           100 non-null    datetime64[ns]
#  2   type               100 non-null    object
#  3   datetimeable_id    100 non-null    int64
#  4   datetimeable_type  100 non-null    object
#  5   created_at         100 non-null    datetime64[ns]
#  6   updated_at         100 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), int64(2), object(2)
# memory usage: 5.6+ KB
